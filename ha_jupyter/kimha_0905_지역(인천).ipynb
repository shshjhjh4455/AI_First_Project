# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#데이터 불러오기
df = pd.read_csv('C:/Users/hyha1/Documents/GitHub/AI_First_Project/customer_payment_data.csv', encoding='cp949')

# %%
def region_extract(df, region:str):
    date = df['날짜']
    col = df.columns
    
    region_col = [c for c in col if c[:2] == region]
#    print(region_col)
    region_df = df[region_col]
    region_df.insert(0, '날짜', date)
#    print(region_df.head())
    return region_df

# %%
## 2017년부터 자료 추출 

for i in range(len(df)):
    if df['날짜'][i] == '2017/01':
        df = df[i:]
df
# Out:
#           날짜     전국_합계  전국_종합소매   전국_백화점  전국_대형마트/유통전문점  전국_슈퍼마켓   전국_편의점  \
# 84   2017/01  37057619  6459281  1246031        2827678  1782019   459685
# 85   2017/02  34209309  5187107  1081967        2150197  1384820   422202
# 86   2017/03  38393522  6097912  1227898        2575103  1642004   498860
# 87   2017/04  37401138  5945479  1182927        2473578  1627104   496490
# 88   2017/05  39487958  6782586  1380424        2843985  1808414   571906
# ..       ...       ...      ...      ...            ...      ...      ...
# 144  2022/01  54539492  7634707  1604401        3165932  1942293   873099
# 145  2022/02  47029608  6265129  1286777        2575148  1565735   792786
# 146  2022/03  53934645  7178711  1493279        2868236  1811634   956231
# 147  2022/04  55138961  7279162  1627246        2873688  1773061   941861
# 148  2022/05  58451416  8115289  1871565        3235987  1906653  1028676
#
#      전국_면세점  전국_전자상거래/통신판매   전국_식료품  ...  기타_오락/문화  기타_스포츠/오락/여가  기타_서적/문구  \
# ...

# %%
r_df = region_extract(df, '인천')
r_df.head()
# Out:
#          날짜    인천_합계  인천_종합소매  인천_백화점  인천_대형마트/유통전문점  인천_슈퍼마켓  인천_편의점  인천_면세점  \
# 84  2017/01  1220175   333086   44066         140714    75238   24362   48705
# 85  2017/02  1120659   277803   38437         105307    59108   22223   52727
# 86  2017/03  1303124   321784   43675         128795    71664   26389   51260
# 87  2017/04  1248042   311593   42833         121051    70664   26061   50984
# 88  2017/05  1334478   356844   47329         142860    77204   30349   59101
#
#     인천_전자상거래/통신판매  인천_식료품  ...  인천_오락/문화  인천_스포츠/오락/여가  인천_서적/문구  인천_교육  \
# 84           5772   50282  ...     42478         36158      6319  41126
# 85           4048   29290  ...     41887         35542      6345  44786
# 86           5177   34787  ...     55702         45543     10159  47361
# 87           4152   35977  ...     52668         45810      6859  43069
# 88           4870   40062  ...     57629         50979      6650  43714
#
#     인천_숙박/음식  인천_숙박  인천_음식점  인천_공과금/개인및전문서비스  인천_금융/보험  인천_기타
# ...

# %%
month_2017 = r_df[r_df['날짜'].between('2017/01', '2017/12')]
month_2018 = r_df[r_df['날짜'].between('2018/01', '2018/12')]
month_2019 = r_df[r_df['날짜'].between('2019/01', '2019/12')]
month_2020 = r_df[r_df['날짜'].between('2020/01', '2020/12')]
month_2021 = r_df[r_df['날짜'].between('2021/01', '2021/12')]
month_2022 = r_df[r_df['날짜'].between('2022/01', '2022/12')]

# %%
month_2017.head()
# Out:
#          날짜    인천_합계  인천_종합소매  인천_백화점  인천_대형마트/유통전문점  인천_슈퍼마켓  인천_편의점  인천_면세점  \
# 84  2017/01  1220175   333086   44066         140714    75238   24362   48705
# 85  2017/02  1120659   277803   38437         105307    59108   22223   52727
# 86  2017/03  1303124   321784   43675         128795    71664   26389   51260
# 87  2017/04  1248042   311593   42833         121051    70664   26061   50984
# 88  2017/05  1334478   356844   47329         142860    77204   30349   59101
#
#     인천_전자상거래/통신판매  인천_식료품  ...  인천_오락/문화  인천_스포츠/오락/여가  인천_서적/문구  인천_교육  \
# 84           5772   50282  ...     42478         36158      6319  41126
# 85           4048   29290  ...     41887         35542      6345  44786
# 86           5177   34787  ...     55702         45543     10159  47361
# 87           4152   35977  ...     52668         45810      6859  43069
# 88           4870   40062  ...     57629         50979      6650  43714
#
#     인천_숙박/음식  인천_숙박  인천_음식점  인천_공과금/개인및전문서비스  인천_금융/보험  인천_기타
# ...

# %%
month_2017.set_index('날짜', inplace=True)
month_2018.set_index('날짜', inplace=True)
month_2019.set_index('날짜', inplace=True)
month_2020.set_index('날짜', inplace=True)
month_2021.set_index('날짜', inplace=True)
month_2022.set_index('날짜', inplace=True)

# %%
month_2022
# Out:
#            인천_합계  인천_종합소매  인천_백화점  인천_대형마트/유통전문점  인천_슈퍼마켓  인천_편의점  인천_면세점  \
# 날짜
# 2022/01  1169894   287151   52123         112392    76714   41567    4356
# 2022/02  1032215   250152   42518          97217    65998   39747    4672
# 2022/03  1240038   291155   51289         109438    76535   48240    5653
# 2022/04  1308327   298545   58362         108847    74737   47319    9281
# 2022/05  1434423   330456   62350         123060    80151   51908   12988
#
#          인천_전자상거래/통신판매  인천_식료품  인천_일반식료품  ...  인천_오락/문화  인천_스포츠/오락/여가  \
# 날짜                                        ...
# 2022/01           2366   65311     60932  ...     38309         33261
# 2022/02           2044   42202     39973  ...     35071         30681
# 2022/03           2646   46943     44287  ...     50866         44885
# 2022/04           2369   50466     47566  ...     59727         54498
# 2022/05           3004   55362     51996  ...     69219         63787
#
# ...

# %%
x_2017 = month_2017.sum()
x_2018 = month_2018.sum()
x_2019 = month_2019.sum()
x_2020 = month_2020.sum()
x_2021 = month_2021.sum()
x_2022 = month_2022.sum()

# %%
sum_df = pd.DataFrame(pd.concat([pd.DataFrame(x_2017).T, pd.DataFrame(x_2018).T, pd.DataFrame(x_2019).T, pd.DataFrame(x_2020).T, 
           pd.DataFrame(x_2021).T, pd.DataFrame(x_2022).T], axis=0))

sum_df
# Out:
#       인천_합계  인천_종합소매  인천_백화점  인천_대형마트/유통전문점  인천_슈퍼마켓  인천_편의점  인천_면세점  \
# 0  15313244  3998405  525718        1568476   885442  358683  660084
# 0  16268266  4213884  530821        1596178   952059  440543  694279
# 0  15833757  4130555  549479        1491345   933127  468989  687611
# 0  14056413  3442423  492017        1377114   979309  492536  101450
# 0  14070674  3457846  590112        1343731   940903  543740   39362
# 0   6184897  1457459  266642         550954   374135  228781   36950
#
#    인천_전자상거래/통신판매  인천_식료품  인천_일반식료품  ...  인천_오락/문화  인천_스포츠/오락/여가  인천_서적/문구  \
# 0          58443  467037    427350  ...    612944        530687     82256
# 0          78270  502996    461257  ...    643813        558871     84941
# 0          91771  504200    461570  ...    665196        585588     79610
# 0         113898  564281    523565  ...    552268        489135     63132
# 0          32137  633367    595992  ...    567655        505857     61800
# ...

# %%
sum_df['year'] = ['2017','2018','2019','2020','2021','2022']

# %%
sum_df=sum_df.set_index('year')

# %%
sum_df
# Out:
#          인천_합계  인천_종합소매  인천_백화점  인천_대형마트/유통전문점  인천_슈퍼마켓  인천_편의점  인천_면세점  \
# year
# 2017  15313244  3998405  525718        1568476   885442  358683  660084
# 2018  16268266  4213884  530821        1596178   952059  440543  694279
# 2019  15833757  4130555  549479        1491345   933127  468989  687611
# 2020  14056413  3442423  492017        1377114   979309  492536  101450
# 2021  14070674  3457846  590112        1343731   940903  543740   39362
# 2022   6184897  1457459  266642         550954   374135  228781   36950
#
#       인천_전자상거래/통신판매  인천_식료품  인천_일반식료품  ...  인천_오락/문화  인천_스포츠/오락/여가  인천_서적/문구  \
# year                                   ...
# 2017          58443  467037    427350  ...    612944        530687     82256
# 2018          78270  502996    461257  ...    643813        558871     84941
# 2019          91771  504200    461570  ...    665196        585588     79610
# 2020         113898  564281    523565  ...    552268        489135     63132
# ...

# %%
compare_df1 = pd.DataFrame(pd.concat([x_2020, x_2021], axis=1))
compare_df1.columns = ['2020', '2021']
compare_df1
# Out:
#                      2020      2021
# 인천_합계            14056413  14070674
# 인천_종합소매           3442423   3457846
# 인천_백화점             492017    590112
# 인천_대형마트/유통전문점     1377114   1343731
# 인천_슈퍼마켓            979309    940903
# 인천_편의점             492536    543740
# 인천_면세점             101450     39362
# 인천_전자상거래/통신판매      113898     32137
# 인천_식료품             564281    633367
# 인천_일반식료품           523565    595992
# 인천_건강보조식품           40718     37376
# 인천_의류/잡화           486625    487051
# 인천_의복/직물           229008    228518
# 인천_복식잡화             64306     62047
# 인천_시계/귀금속/안경        94837    105725
# 인천_화장품              98476     90762
# 인천_연료             1322753   1499834
# 인천_가구/가전           487093    439695
# 인천_가구              110006     88121
# 인천_가전제품/정보통신기기     377088    351577
# 인천_의료/보건          1774796   1829910
# 인천_종합병원            394164    414125
# 인천_일반병의원/기타의료기관   1380630   1415785
# 인천_자동차            1005652    914283
# 인천_국산자동차신품         504082    363787
# ...

# %%
compare_df1['증감율'] = ((compare_df1['2021'] - compare_df1['2020'])/compare_df1['2020'] * 100)
compare_df1
# Out:
#                      2020      2021        증감율
# 인천_합계            14056413  14070674   0.101455
# 인천_종합소매           3442423   3457846   0.448027
# 인천_백화점             492017    590112  19.937319
# 인천_대형마트/유통전문점     1377114   1343731  -2.424128
# 인천_슈퍼마켓            979309    940903  -3.921745
# 인천_편의점             492536    543740  10.395991
# 인천_면세점             101450     39362 -61.200591
# 인천_전자상거래/통신판매      113898     32137 -71.784404
# 인천_식료품             564281    633367  12.243191
# 인천_일반식료품           523565    595992  13.833430
# 인천_건강보조식품           40718     37376  -8.207672
# 인천_의류/잡화           486625    487051   0.087542
# 인천_의복/직물           229008    228518  -0.213966
# 인천_복식잡화             64306     62047  -3.512891
# 인천_시계/귀금속/안경        94837    105725  11.480751
# 인천_화장품              98476     90762  -7.833381
# 인천_연료             1322753   1499834  13.387307
# 인천_가구/가전           487093    439695  -9.730791
# 인천_가구              110006     88121 -19.894369
# ...

# %%
compare_df1['증감율'] = ((compare_df1['2021'] - compare_df1['2020'])/compare_df1['2020'] * 100) > 10
compare_df1
# Out:
#                      2020      2021    증감율
# 인천_합계            14056413  14070674  False
# 인천_종합소매           3442423   3457846  False
# 인천_백화점             492017    590112   True
# 인천_대형마트/유통전문점     1377114   1343731  False
# 인천_슈퍼마켓            979309    940903  False
# 인천_편의점             492536    543740   True
# 인천_면세점             101450     39362  False
# 인천_전자상거래/통신판매      113898     32137  False
# 인천_식료품             564281    633367   True
# 인천_일반식료품           523565    595992   True
# 인천_건강보조식품           40718     37376  False
# 인천_의류/잡화           486625    487051  False
# 인천_의복/직물           229008    228518  False
# 인천_복식잡화             64306     62047  False
# 인천_시계/귀금속/안경        94837    105725   True
# 인천_화장품              98476     90762  False
# 인천_연료             1322753   1499834   True
# 인천_가구/가전           487093    439695  False
# 인천_가구              110006     88121  False
# 인천_가전제품/정보통신기기     377088    351577  False
# 인천_의료/보건          1774796   1829910  False
# ...

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['인천_편의점'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['인천_편의점'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['인천_전자상거래/통신판매'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['인천_전자상거래/통신판매'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['인천_가구/가전'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['인천_가구/가전'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['인천_가전제품/정보통신기기'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['인천_가전제품/정보통신기기'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['인천_공과금/개인및전문서비스'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['인천_공과금/개인및전문서비스'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['인천_기타'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['인천_기타'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()
