# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#데이터 불러오기
df = pd.read_csv('C:/Users/hyha1/Documents/GitHub/AI_First_Project/customer_payment_data.csv', encoding='cp949')

# %%
def region_extract(df, region:str):
    date = df['날짜']
    col = df.columns
    
    region_col = [c for c in col if c[:2] == region]
#    print(region_col)
    region_df = df[region_col]
    region_df.insert(0, '날짜', date)
#    print(region_df.head())
    return region_df

# %%
## 2017년부터 자료 추출 

for i in range(len(df)):
    if df['날짜'][i] == '2017/01':
        df = df[i:]
df
# Out:
#           날짜     전국_합계  전국_종합소매   전국_백화점  전국_대형마트/유통전문점  전국_슈퍼마켓   전국_편의점  \
# 84   2017/01  37057619  6459281  1246031        2827678  1782019   459685
# 85   2017/02  34209309  5187107  1081967        2150197  1384820   422202
# 86   2017/03  38393522  6097912  1227898        2575103  1642004   498860
# 87   2017/04  37401138  5945479  1182927        2473578  1627104   496490
# 88   2017/05  39487958  6782586  1380424        2843985  1808414   571906
# ..       ...       ...      ...      ...            ...      ...      ...
# 144  2022/01  54539492  7634707  1604401        3165932  1942293   873099
# 145  2022/02  47029608  6265129  1286777        2575148  1565735   792786
# 146  2022/03  53934645  7178711  1493279        2868236  1811634   956231
# 147  2022/04  55138961  7279162  1627246        2873688  1773061   941861
# 148  2022/05  58451416  8115289  1871565        3235987  1906653  1028676
#
#      전국_면세점  전국_전자상거래/통신판매   전국_식료품  ...  기타_오락/문화  기타_스포츠/오락/여가  기타_서적/문구  \
# 84   143868        4999376   849868  ...      7471          5886      1585
# 85   147921        4945107   520626  ...      8180          6659      1521
# 86   154048        5470028   625023  ...     10578          8410      2168
# 87   165381        5171797   638792  ...     10302          8859      1443
# 88   177857        5495525   696325  ...     11676         10278      1397
# ..      ...            ...      ...  ...       ...           ...       ...
# 144   48982       13162164  1285590  ...      4354          3425       929
# 145   44683       11902937   798669  ...      3894          3240       654
# 146   49332       13475197   889680  ...      5991          4873      1118
# 147   63306       13032409   947790  ...      6818          6001       817
# 148   72408       13455127  1039780  ...      7637          6826       811
#
#      기타_교육  기타_숙박/음식  기타_숙박  기타_음식점  기타_공과금/개인및전문서비스  기타_금융/보험  기타_기타
# 84    4923     28523   2017   26505            12460     10050  13155
# 85    5300     30726   1924   28803            11116     10680  12480
# 86    5615     30358   1594   28764            11067     11773  13472
# 87    4425     28566   1542   27024            10999     10439  13673
# 88    5227     34962   1930   33032            10708     10840  13638
# ..     ...       ...    ...     ...              ...       ...    ...
# 144   3570     20278   1285   18993            12477      9708  11564
# 145   2949     16696   1119   15578             8438      9109   8890
# 146   3354     19462    998   18465             8745     11769  10594
# 147   3144     22523   1070   21453             8946     10707  11750
# 148   3331     26751   1381   25370             8237      9915  10875
#
# [65 rows x 739 columns]

# %%
r_df = region_extract(df, '부산')
r_df.head()
# Out:
#          날짜    부산_합계  부산_종합소매  부산_백화점  부산_대형마트/유통전문점  부산_슈퍼마켓  부산_편의점  부산_면세점  \
# 84  2017/01  1714642   481412  147538         194055    99633   24642   15543
# 85  2017/02  1552829   388218  128331         144353    75650   22773   17112
# 86  2017/03  1743393   458980  143664         179918    91685   26140   17574
# 87  2017/04  1681701   433890  137140         167450    86685   25937   16678
# 88  2017/05  1812751   498290  163668         192660    93513   30490   17959
#
#     부산_전자상거래/통신판매  부산_식료품  ...  부산_오락/문화  부산_스포츠/오락/여가  부산_서적/문구  부산_교육  \
# 84           6684   45457  ...     56919         49376      7542  45198
# 85           5557   28523  ...     52751         45230      7521  51518
# 86           7137   34096  ...     68883         54711     14172  50002
# 87           5963   33787  ...     64800         56892      7907  44464
# 88           6484   37637  ...     69864         62622      7242  45520
#
#     부산_숙박/음식  부산_숙박  부산_음식점  부산_공과금/개인및전문서비스  부산_금융/보험   부산_기타
# 84    272297  16237  256060            74047      2961  102013
# 85    246184  15962  230222            70966      3121   94093
# 86    263359  14944  248415            73509      3572  103802
# 87    261652  14174  247478            71453      3427  100416
# 88    304105  19315  284789            69180      3375  100269
#
# [5 rows x 42 columns]

# %%
month_2017 = r_df[r_df['날짜'].between('2017/01', '2017/12')]
month_2018 = r_df[r_df['날짜'].between('2018/01', '2018/12')]
month_2019 = r_df[r_df['날짜'].between('2019/01', '2019/12')]
month_2020 = r_df[r_df['날짜'].between('2020/01', '2020/12')]
month_2021 = r_df[r_df['날짜'].between('2021/01', '2021/12')]
month_2022 = r_df[r_df['날짜'].between('2022/01', '2022/12')]

# %%
month_2017.head()
# Out:
#          날짜    부산_합계  부산_종합소매  부산_백화점  부산_대형마트/유통전문점  부산_슈퍼마켓  부산_편의점  부산_면세점  \
# 84  2017/01  1714642   481412  147538         194055    99633   24642   15543
# 85  2017/02  1552829   388218  128331         144353    75650   22773   17112
# 86  2017/03  1743393   458980  143664         179918    91685   26140   17574
# 87  2017/04  1681701   433890  137140         167450    86685   25937   16678
# 88  2017/05  1812751   498290  163668         192660    93513   30490   17959
#
#     부산_전자상거래/통신판매  부산_식료품  ...  부산_오락/문화  부산_스포츠/오락/여가  부산_서적/문구  부산_교육  \
# 84           6684   45457  ...     56919         49376      7542  45198
# 85           5557   28523  ...     52751         45230      7521  51518
# 86           7137   34096  ...     68883         54711     14172  50002
# 87           5963   33787  ...     64800         56892      7907  44464
# 88           6484   37637  ...     69864         62622      7242  45520
#
#     부산_숙박/음식  부산_숙박  부산_음식점  부산_공과금/개인및전문서비스  부산_금융/보험   부산_기타
# 84    272297  16237  256060            74047      2961  102013
# 85    246184  15962  230222            70966      3121   94093
# 86    263359  14944  248415            73509      3572  103802
# 87    261652  14174  247478            71453      3427  100416
# 88    304105  19315  284789            69180      3375  100269
#
# [5 rows x 42 columns]

# %%
month_2017.set_index('날짜', inplace=True)
month_2018.set_index('날짜', inplace=True)
month_2019.set_index('날짜', inplace=True)
month_2020.set_index('날짜', inplace=True)
month_2021.set_index('날짜', inplace=True)
month_2022.set_index('날짜', inplace=True)

# %%
month_2022
# Out:
#            부산_합계  부산_종합소매  부산_백화점  부산_대형마트/유통전문점  부산_슈퍼마켓  부산_편의점  부산_면세점  \
# 날짜
# 2022/01  1920700   560452  209580         199786   107404   43060     621
# 2022/02  1608247   444875  165490         155353    83940   39554     537
# 2022/03  1877769   518732  188106         180382   102537   47070     638
# 2022/04  1952204   524459  205987         174941    97217   45572     742
# 2022/05  2113591   581974  235631         194309   101544   49469    1021
#
#          부산_전자상거래/통신판매  부산_식료품  부산_일반식료품  ...  부산_오락/문화  부산_스포츠/오락/여가  \
# 날짜                                        ...
# 2022/01           7122   67899     62461  ...     49633         42629
# 2022/02           8127   42859     39441  ...     43071         36933
# 2022/03           9156   47693     43634  ...     55034         45851
# 2022/04           9361   50359     45982  ...     62927         55693
# 2022/05           8621   53940     49377  ...     71533         64401
#
#          부산_서적/문구  부산_교육  부산_숙박/음식  부산_숙박  부산_음식점  부산_공과금/개인및전문서비스  부산_금융/보험  \
# 날짜
# 2022/01      7004  52453    249062  21377  227685            94517      1965
# 2022/02      6138  48635    209671  19860  189811            78875      1991
# 2022/03      9184  52895    239259  17323  221936            93190      2490
# 2022/04      7233  48821    294500  19955  274545            93445      2261
# 2022/05      7132  52438    355335  26167  329168            89344      2311
#
#           부산_기타
# 날짜
# 2022/01  124115
# 2022/02  115656
# 2022/03  133288
# 2022/04  143602
# 2022/05  143997
#
# [5 rows x 41 columns]

# %%
x_2017 = month_2017.sum()
x_2018 = month_2018.sum()
x_2019 = month_2019.sum()
x_2020 = month_2020.sum()
x_2021 = month_2021.sum()
x_2022 = month_2022.sum()

# %%
sum_df = pd.DataFrame(pd.concat([pd.DataFrame(x_2017).T, pd.DataFrame(x_2018).T, pd.DataFrame(x_2019).T, pd.DataFrame(x_2020).T, 
           pd.DataFrame(x_2021).T, pd.DataFrame(x_2022).T], axis=0))

sum_df
# Out:
#       부산_합계  부산_종합소매   부산_백화점  부산_대형마트/유통전문점  부산_슈퍼마켓  부산_편의점  부산_면세점  \
# 0  20890489  5633343  1795503        2167187  1115564  358814  196273
# 0  21711735  5899035  1894926        2213796  1174114  426416  189783
# 0  22310722  5901834  1927153        2152678  1186156  472217  163631
# 0  20535219  5624863  1780202        2148931  1208351  469386   17993
# 0  21582504  6100339  2153839        2210915  1204960  523864    6761
# 0   9472511  2630492  1004794         904771   492642  224725    3559
#
#    부산_전자상거래/통신판매  부산_식료품  부산_일반식료품  ...  부산_오락/문화  부산_스포츠/오락/여가  부산_서적/문구  \
# 0          68591  445627    382359  ...    761116        661261     99854
# 0         105000  489722    435651  ...    764271        665089     99183
# 0          88036  514975    460668  ...    773302        672726    100576
# 0         118168  536301    481231  ...    602424        520162     82262
# 0          63807  599837    550608  ...    636618        550048     86569
# 0          42387  262750    240895  ...    282198        245507     36691
#
#     부산_교육  부산_숙박/음식   부산_숙박   부산_음식점  부산_공과금/개인및전문서비스  부산_금융/보험    부산_기타
# 0  575254   3391571  221804  3169770           852030     40343  1238233
# 0  608831   3629221  238419  3390798           848943     52422  1308266
# 0  662850   3804269  244839  3559431           930227     46580  1400006
# 0  530657   3031993  181546  2850445           943607     38881  1428008
# 0  638970   2995917  224973  2770944          1008549     30690  1461721
# 0  255242   1347827  104682  1243145           449371     11018   660658
#
# [6 rows x 41 columns]

# %%
sum_df['year'] = ['2017','2018','2019','2020','2021','2022']

# %%
sum_df=sum_df.set_index('year')

# %%
sum_df
# Out:
#          부산_합계  부산_종합소매   부산_백화점  부산_대형마트/유통전문점  부산_슈퍼마켓  부산_편의점  부산_면세점  \
# year
# 2017  20890489  5633343  1795503        2167187  1115564  358814  196273
# 2018  21711735  5899035  1894926        2213796  1174114  426416  189783
# 2019  22310722  5901834  1927153        2152678  1186156  472217  163631
# 2020  20535219  5624863  1780202        2148931  1208351  469386   17993
# 2021  21582504  6100339  2153839        2210915  1204960  523864    6761
# 2022   9472511  2630492  1004794         904771   492642  224725    3559
#
#       부산_전자상거래/통신판매  부산_식료품  부산_일반식료품  ...  부산_오락/문화  부산_스포츠/오락/여가  부산_서적/문구  \
# year                                   ...
# 2017          68591  445627    382359  ...    761116        661261     99854
# 2018         105000  489722    435651  ...    764271        665089     99183
# 2019          88036  514975    460668  ...    773302        672726    100576
# 2020         118168  536301    481231  ...    602424        520162     82262
# 2021          63807  599837    550608  ...    636618        550048     86569
# 2022          42387  262750    240895  ...    282198        245507     36691
#
#        부산_교육  부산_숙박/음식   부산_숙박   부산_음식점  부산_공과금/개인및전문서비스  부산_금융/보험    부산_기타
# year
# 2017  575254   3391571  221804  3169770           852030     40343  1238233
# 2018  608831   3629221  238419  3390798           848943     52422  1308266
# 2019  662850   3804269  244839  3559431           930227     46580  1400006
# 2020  530657   3031993  181546  2850445           943607     38881  1428008
# 2021  638970   2995917  224973  2770944          1008549     30690  1461721
# 2022  255242   1347827  104682  1243145           449371     11018   660658
#
# [6 rows x 41 columns]

# %%
compare_df1 = pd.DataFrame(pd.concat([x_2017, x_2018], axis=1))
compare_df1.columns = ['2017', '2018']
compare_df1
# Out:
#                      2017      2018
# 부산_합계            20890489  21711735
# 부산_종합소매           5633343   5899035
# 부산_백화점            1795503   1894926
# 부산_대형마트/유통전문점     2167187   2213796
# 부산_슈퍼마켓           1115564   1174114
# 부산_편의점             358814    426416
# 부산_면세점             196273    189783
# 부산_전자상거래/통신판매       68591    105000
# 부산_식료품             445627    489722
# 부산_일반식료품           382359    435651
# 부산_건강보조식품           63264     54069
# 부산_의류/잡화           980043    936944
# 부산_의복/직물           544436    514749
# 부산_복식잡화             79393     79074
# 부산_시계/귀금속/안경       167377    167643
# 부산_화장품             188840    175481
# 부산_연료             1593162   1730002
# 부산_가구/가전           656866    669840
# 부산_가구              106478    111002
# 부산_가전제품/정보통신기기     550386    558839
# 부산_의료/보건          2715181   2889637
# 부산_종합병원            591099    610886
# 부산_일반병의원/기타의료기관   2124082   2278752
# 부산_자동차            1365377   1139885
# 부산_국산자동차신품         799284    557180
# 부산_기타운송수단           91425     88309
# 부산_자동차부품및정비        474671    494398
# 부산_여행/교통           573758    639712
# 부산_여행사/자동차임대        21515     25301
# 부산_항공사             250450    286660
# 부산_대중교통            301790    327751
# 부산_오락/문화           761116    764271
# 부산_스포츠/오락/여가       661261    665089
# 부산_서적/문구            99854     99183
# 부산_교육              575254    608831
# 부산_숙박/음식          3391571   3629221
# 부산_숙박              221804    238419
# 부산_음식점            3169770   3390798
# 부산_공과금/개인및전문서비스    852030    848943
# 부산_금융/보험            40343     52422
# 부산_기타             1238233   1308266

# %%
compare_df1['증감율'] = ((compare_df1['2018'] - compare_df1['2017'])/compare_df1['2017'] * 100)
compare_df1
# Out:
#                      2017      2018        증감율
# 부산_합계            20890489  21711735   3.931196
# 부산_종합소매           5633343   5899035   4.716418
# 부산_백화점            1795503   1894926   5.537334
# 부산_대형마트/유통전문점     2167187   2213796   2.150668
# 부산_슈퍼마켓           1115564   1174114   5.248466
# 부산_편의점             358814    426416  18.840402
# 부산_면세점             196273    189783  -3.306619
# 부산_전자상거래/통신판매       68591    105000  53.081308
# 부산_식료품             445627    489722   9.895047
# 부산_일반식료품           382359    435651  13.937687
# 부산_건강보조식품           63264     54069 -14.534332
# 부산_의류/잡화           980043    936944  -4.397664
# 부산_의복/직물           544436    514749  -5.452799
# 부산_복식잡화             79393     79074  -0.401799
# 부산_시계/귀금속/안경       167377    167643   0.158923
# 부산_화장품             188840    175481  -7.074243
# 부산_연료             1593162   1730002   8.589208
# 부산_가구/가전           656866    669840   1.975136
# 부산_가구              106478    111002   4.248765
# 부산_가전제품/정보통신기기     550386    558839   1.535831
# 부산_의료/보건          2715181   2889637   6.425207
# 부산_종합병원            591099    610886   3.347493
# 부산_일반병의원/기타의료기관   2124082   2278752   7.281734
# 부산_자동차            1365377   1139885 -16.514999
# 부산_국산자동차신품         799284    557180 -30.290110
# 부산_기타운송수단           91425     88309  -3.408258
# 부산_자동차부품및정비        474671    494398   4.155931
# 부산_여행/교통           573758    639712  11.495090
# 부산_여행사/자동차임대        21515     25301  17.597025
# 부산_항공사             250450    286660  14.457976
# 부산_대중교통            301790    327751   8.602339
# 부산_오락/문화           761116    764271   0.414523
# 부산_스포츠/오락/여가       661261    665089   0.578894
# 부산_서적/문구            99854     99183  -0.671981
# 부산_교육              575254    608831   5.836900
# 부산_숙박/음식          3391571   3629221   7.007077
# 부산_숙박              221804    238419   7.490848
# 부산_음식점            3169770   3390798   6.972998
# 부산_공과금/개인및전문서비스    852030    848943  -0.362311
# 부산_금융/보험            40343     52422  29.940758
# 부산_기타             1238233   1308266   5.655882

# %%
compare_df1['증감율'] = ((compare_df1['2018'] - compare_df1['2017'])/compare_df1['2017'] * 100) > 10
compare_df1
# Out:
#                      2017      2018    증감율
# 부산_합계            20890489  21711735  False
# 부산_종합소매           5633343   5899035  False
# 부산_백화점            1795503   1894926  False
# 부산_대형마트/유통전문점     2167187   2213796  False
# 부산_슈퍼마켓           1115564   1174114  False
# 부산_편의점             358814    426416   True
# 부산_면세점             196273    189783  False
# 부산_전자상거래/통신판매       68591    105000   True
# 부산_식료품             445627    489722  False
# 부산_일반식료품           382359    435651   True
# 부산_건강보조식품           63264     54069  False
# 부산_의류/잡화           980043    936944  False
# 부산_의복/직물           544436    514749  False
# 부산_복식잡화             79393     79074  False
# 부산_시계/귀금속/안경       167377    167643  False
# 부산_화장품             188840    175481  False
# 부산_연료             1593162   1730002  False
# 부산_가구/가전           656866    669840  False
# 부산_가구              106478    111002  False
# 부산_가전제품/정보통신기기     550386    558839  False
# 부산_의료/보건          2715181   2889637  False
# 부산_종합병원            591099    610886  False
# 부산_일반병의원/기타의료기관   2124082   2278752  False
# 부산_자동차            1365377   1139885  False
# 부산_국산자동차신품         799284    557180  False
# 부산_기타운송수단           91425     88309  False
# 부산_자동차부품및정비        474671    494398  False
# 부산_여행/교통           573758    639712   True
# 부산_여행사/자동차임대        21515     25301   True
# 부산_항공사             250450    286660   True
# 부산_대중교통            301790    327751  False
# 부산_오락/문화           761116    764271  False
# 부산_스포츠/오락/여가       661261    665089  False
# 부산_서적/문구            99854     99183  False
# 부산_교육              575254    608831  False
# 부산_숙박/음식          3391571   3629221  False
# 부산_숙박              221804    238419  False
# 부산_음식점            3169770   3390798  False
# 부산_공과금/개인및전문서비스    852030    848943  False
# 부산_금융/보험            40343     52422   True
# 부산_기타             1238233   1308266  False

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['부산_편의점'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['부산_편의점'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['부산_전자상거래/통신판매'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['부산_전자상거래/통신판매'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['부산_일반식료품'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['부산_일반식료품'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['부산_여행/교통'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['부산_여행/교통'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['부산_여행사/자동차임대'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['부산_여행사/자동차임대'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['부산_항공사'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['부산_항공사'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['부산_금융/보험'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['부산_금융/보험'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()
