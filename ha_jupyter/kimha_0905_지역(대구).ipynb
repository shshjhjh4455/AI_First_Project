# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#데이터 불러오기
df = pd.read_csv('C:/Users/hyha1/Documents/GitHub/AI_First_Project/customer_payment_data.csv', encoding='cp949')

# %%
def region_extract(df, region:str):
    date = df['날짜']
    col = df.columns
    
    region_col = [c for c in col if c[:2] == region]
#    print(region_col)
    region_df = df[region_col]
    region_df.insert(0, '날짜', date)
#    print(region_df.head())
    return region_df

# %%
## 2017년부터 자료 추출 

for i in range(len(df)):
    if df['날짜'][i] == '2017/01':
        df = df[i:]
df
# Out:
#           날짜     전국_합계  전국_종합소매   전국_백화점  전국_대형마트/유통전문점  전국_슈퍼마켓   전국_편의점  \
# 84   2017/01  37057619  6459281  1246031        2827678  1782019   459685
# 85   2017/02  34209309  5187107  1081967        2150197  1384820   422202
# 86   2017/03  38393522  6097912  1227898        2575103  1642004   498860
# 87   2017/04  37401138  5945479  1182927        2473578  1627104   496490
# 88   2017/05  39487958  6782586  1380424        2843985  1808414   571906
# ..       ...       ...      ...      ...            ...      ...      ...
# 144  2022/01  54539492  7634707  1604401        3165932  1942293   873099
# 145  2022/02  47029608  6265129  1286777        2575148  1565735   792786
# 146  2022/03  53934645  7178711  1493279        2868236  1811634   956231
# 147  2022/04  55138961  7279162  1627246        2873688  1773061   941861
# 148  2022/05  58451416  8115289  1871565        3235987  1906653  1028676
#
#      전국_면세점  전국_전자상거래/통신판매   전국_식료품  ...  기타_오락/문화  기타_스포츠/오락/여가  기타_서적/문구  \
# 84   143868        4999376   849868  ...      7471          5886      1585
# 85   147921        4945107   520626  ...      8180          6659      1521
# 86   154048        5470028   625023  ...     10578          8410      2168
# 87   165381        5171797   638792  ...     10302          8859      1443
# 88   177857        5495525   696325  ...     11676         10278      1397
# ..      ...            ...      ...  ...       ...           ...       ...
# 144   48982       13162164  1285590  ...      4354          3425       929
# 145   44683       11902937   798669  ...      3894          3240       654
# 146   49332       13475197   889680  ...      5991          4873      1118
# 147   63306       13032409   947790  ...      6818          6001       817
# 148   72408       13455127  1039780  ...      7637          6826       811
#
#      기타_교육  기타_숙박/음식  기타_숙박  기타_음식점  기타_공과금/개인및전문서비스  기타_금융/보험  기타_기타
# 84    4923     28523   2017   26505            12460     10050  13155
# 85    5300     30726   1924   28803            11116     10680  12480
# 86    5615     30358   1594   28764            11067     11773  13472
# 87    4425     28566   1542   27024            10999     10439  13673
# 88    5227     34962   1930   33032            10708     10840  13638
# ..     ...       ...    ...     ...              ...       ...    ...
# 144   3570     20278   1285   18993            12477      9708  11564
# 145   2949     16696   1119   15578             8438      9109   8890
# 146   3354     19462    998   18465             8745     11769  10594
# 147   3144     22523   1070   21453             8946     10707  11750
# 148   3331     26751   1381   25370             8237      9915  10875
#
# [65 rows x 739 columns]

# %%
r_df = region_extract(df, '대구')
r_df.head()
# Out:
#          날짜    대구_합계  대구_종합소매  대구_백화점  대구_대형마트/유통전문점  대구_슈퍼마켓  대구_편의점  대구_면세점  \
# 84  2017/01  1039020   291782  100429         112302    65955   12475     621
# 85  2017/02   936968   232800   83791          83444    53413   11570     582
# 86  2017/03  1055248   268822   93485          98946    62049   13700     643
# 87  2017/04  1028803   263270   90448          95345    63095   13737     645
# 88  2017/05  1112177   302970  105087         113187    68195   15833     669
#
#     대구_전자상거래/통신판매  대구_식료품  ...  대구_오락/문화  대구_스포츠/오락/여가  대구_서적/문구  대구_교육  \
# 84           8041   34594  ...     39667         32421      7246  34846
# 85           9841   21296  ...     36530         29335      7195  39102
# 86          11688   24720  ...     47378         35129     12249  40179
# 87           9808   24860  ...     41889         34430      7459  35968
# 88           8947   26301  ...     44016         36431      7585  36874
#
#     대구_숙박/음식  대구_숙박  대구_음식점  대구_공과금/개인및전문서비스  대구_금융/보험  대구_기타
# 84    166214   5224  160991            32277       657  65656
# 85    148927   4694  144234            30808      1222  59050
# 86    163171   4695  158476            34049      1739  65946
# 87    166160   5701  160458            30579      1308  64517
# 88    182912   5850  177062            35956      1247  66026
#
# [5 rows x 42 columns]

# %%
month_2017 = r_df[r_df['날짜'].between('2017/01', '2017/12')]
month_2018 = r_df[r_df['날짜'].between('2018/01', '2018/12')]
month_2019 = r_df[r_df['날짜'].between('2019/01', '2019/12')]
month_2020 = r_df[r_df['날짜'].between('2020/01', '2020/12')]
month_2021 = r_df[r_df['날짜'].between('2021/01', '2021/12')]
month_2022 = r_df[r_df['날짜'].between('2022/01', '2022/12')]

# %%
month_2017.head()
# Out:
#          날짜    대구_합계  대구_종합소매  대구_백화점  대구_대형마트/유통전문점  대구_슈퍼마켓  대구_편의점  대구_면세점  \
# 84  2017/01  1039020   291782  100429         112302    65955   12475     621
# 85  2017/02   936968   232800   83791          83444    53413   11570     582
# 86  2017/03  1055248   268822   93485          98946    62049   13700     643
# 87  2017/04  1028803   263270   90448          95345    63095   13737     645
# 88  2017/05  1112177   302970  105087         113187    68195   15833     669
#
#     대구_전자상거래/통신판매  대구_식료품  ...  대구_오락/문화  대구_스포츠/오락/여가  대구_서적/문구  대구_교육  \
# 84           8041   34594  ...     39667         32421      7246  34846
# 85           9841   21296  ...     36530         29335      7195  39102
# 86          11688   24720  ...     47378         35129     12249  40179
# 87           9808   24860  ...     41889         34430      7459  35968
# 88           8947   26301  ...     44016         36431      7585  36874
#
#     대구_숙박/음식  대구_숙박  대구_음식점  대구_공과금/개인및전문서비스  대구_금융/보험  대구_기타
# 84    166214   5224  160991            32277       657  65656
# 85    148927   4694  144234            30808      1222  59050
# 86    163171   4695  158476            34049      1739  65946
# 87    166160   5701  160458            30579      1308  64517
# 88    182912   5850  177062            35956      1247  66026
#
# [5 rows x 42 columns]

# %%
month_2017.set_index('날짜', inplace=True)
month_2018.set_index('날짜', inplace=True)
month_2019.set_index('날짜', inplace=True)
month_2020.set_index('날짜', inplace=True)
month_2021.set_index('날짜', inplace=True)
month_2022.set_index('날짜', inplace=True)

# %%
month_2022
# Out:
#            대구_합계  대구_종합소매  대구_백화점  대구_대형마트/유통전문점  대구_슈퍼마켓  대구_편의점  대구_면세점  \
# 날짜
# 2022/01  1237668   332677  121411          97123    83811   30318      14
# 2022/02   995607   264194   98962          72193    65897   27123      20
# 2022/03  1197002   304777  114824          81804    75165   32962      22
# 2022/04  1243968   307324  121007          80842    73322   32125      28
# 2022/05  1341863   345787  139068          91720    79745   35191      64
#
#          대구_전자상거래/통신판매  대구_식료품  대구_일반식료품  ...  대구_오락/문화  대구_스포츠/오락/여가  \
# 날짜                                        ...
# 2022/01          16508   61732     58711  ...     34781         28400
# 2022/02           2488   37895     36090  ...     28875         23419
# 2022/03          12521   41897     39913  ...     38823         29885
# 2022/04          16729   40825     38711  ...     40719         34383
# 2022/05           3249   44520     42130  ...     46647         39966
#
#          대구_서적/문구  대구_교육  대구_숙박/음식  대구_숙박  대구_음식점  대구_공과금/개인및전문서비스  대구_금융/보험  \
# 날짜
# 2022/01      6381  45634    156650   4756  151894            49035       668
# 2022/02      5456  38396    125787   4655  121132            42933       798
# 2022/03      8938  43759    157508   5087  152421            48293      1210
# 2022/04      6336  40097    184447   6797  177651            47029      1071
# 2022/05      6681  45027    226202   7790  218412            44590       890
#
#          대구_기타
# 날짜
# 2022/01  75239
# 2022/02  68070
# 2022/03  83232
# 2022/04  86422
# 2022/05  88984
#
# [5 rows x 41 columns]

# %%
x_2017 = month_2017.sum()
x_2018 = month_2018.sum()
x_2019 = month_2019.sum()
x_2020 = month_2020.sum()
x_2021 = month_2021.sum()
x_2022 = month_2022.sum()

# %%
sum_df = pd.DataFrame(pd.concat([pd.DataFrame(x_2017).T, pd.DataFrame(x_2018).T, pd.DataFrame(x_2019).T, pd.DataFrame(x_2020).T, 
           pd.DataFrame(x_2021).T, pd.DataFrame(x_2022).T], axis=0))

sum_df
# Out:
#       대구_합계  대구_종합소매   대구_백화점  대구_대형마트/유통전문점  대구_슈퍼마켓  대구_편의점  대구_면세점  \
# 0  12738896  3371537  1138770        1256821   777762  190043    8142
# 0  13498323  3494897  1162093        1248558   830855  244458    8932
# 0  13931167  3530305  1208177        1160726   864509  286360   10527
# 0  12722569  3311379  1038067        1064951   902659  304334    1367
# 0  13698697  3631539  1337098        1044531   897714  352083     114
# 0   6016108  1554759   595272         423682   377940  157719     148
#
#    대구_전자상거래/통신판매  대구_식료품  대구_일반식료품  ...  대구_오락/문화  대구_스포츠/오락/여가  대구_서적/문구  \
# 0          79195  326073    296671  ...    490873        398456     92418
# 0          96510  365691    335963  ...    481962        392092     89866
# 0         102494  402450    373803  ...    491680        402157     89522
# 0         125982  459621    433357  ...    384951        311526     73426
# 0          84050  507926    483032  ...    425473        348555     76916
# 0          51495  226869    215555  ...    189845        156053     33792
#
#     대구_교육  대구_숙박/음식  대구_숙박   대구_음식점  대구_공과금/개인및전문서비스  대구_금융/보험   대구_기타
# 0  457699   2070278  63184  2007095           378017     13585  778255
# 0  485557   2242656  66649  2176009           431785     14369  831742
# 0  531692   2354905  74917  2279987           472614     14211  911250
# 0  423098   1926290  49109  1877180           435530     15553  883274
# 0  507424   1934406  57589  1876813           474500     11054  921193
# 0  212913    850594  29085   821510           231880      4637  401947
#
# [6 rows x 41 columns]

# %%
sum_df['year'] = ['2017','2018','2019','2020','2021','2022']

# %%
sum_df=sum_df.set_index('year')

# %%
sum_df
# Out:
#          대구_합계  대구_종합소매   대구_백화점  대구_대형마트/유통전문점  대구_슈퍼마켓  대구_편의점  대구_면세점  \
# year
# 2017  12738896  3371537  1138770        1256821   777762  190043    8142
# 2018  13498323  3494897  1162093        1248558   830855  244458    8932
# 2019  13931167  3530305  1208177        1160726   864509  286360   10527
# 2020  12722569  3311379  1038067        1064951   902659  304334    1367
# 2021  13698697  3631539  1337098        1044531   897714  352083     114
# 2022   6016108  1554759   595272         423682   377940  157719     148
#
#       대구_전자상거래/통신판매  대구_식료품  대구_일반식료품  ...  대구_오락/문화  대구_스포츠/오락/여가  대구_서적/문구  \
# year                                   ...
# 2017          79195  326073    296671  ...    490873        398456     92418
# 2018          96510  365691    335963  ...    481962        392092     89866
# 2019         102494  402450    373803  ...    491680        402157     89522
# 2020         125982  459621    433357  ...    384951        311526     73426
# 2021          84050  507926    483032  ...    425473        348555     76916
# 2022          51495  226869    215555  ...    189845        156053     33792
#
#        대구_교육  대구_숙박/음식  대구_숙박   대구_음식점  대구_공과금/개인및전문서비스  대구_금융/보험   대구_기타
# year
# 2017  457699   2070278  63184  2007095           378017     13585  778255
# 2018  485557   2242656  66649  2176009           431785     14369  831742
# 2019  531692   2354905  74917  2279987           472614     14211  911250
# 2020  423098   1926290  49109  1877180           435530     15553  883274
# 2021  507424   1934406  57589  1876813           474500     11054  921193
# 2022  212913    850594  29085   821510           231880      4637  401947
#
# [6 rows x 41 columns]

# %%
compare_df1 = pd.DataFrame(pd.concat([x_2020, x_2021], axis=1))
compare_df1.columns = ['2020', '2021']
compare_df1
# Out:
#                      2020      2021
# 대구_합계            12722569  13698697
# 대구_종합소매           3311379   3631539
# 대구_백화점            1038067   1337098
# 대구_대형마트/유통전문점     1064951   1044531
# 대구_슈퍼마켓            902659    897714
# 대구_편의점             304334    352083
# 대구_면세점               1367       114
# 대구_전자상거래/통신판매      125982     84050
# 대구_식료품             459621    507926
# 대구_일반식료품           433357    483032
# 대구_건강보조식품           26264     24893
# 대구_의류/잡화           505470    528994
# 대구_의복/직물           258954    272334
# 대구_복식잡화             37506     41103
# 대구_시계/귀금속/안경       118672    129854
# 대구_화장품              90339     85707
# 대구_연료             1133595   1321584
# 대구_가구/가전           467335    422270
# 대구_가구               81432     64782
# 대구_가전제품/정보통신기기     385903    357488
# 대구_의료/보건          2102621   2324223
# 대구_종합병원            354248    405855
# 대구_일반병의원/기타의료기관   1748374   1918367
# 대구_자동차             415598    455998
# 대구_국산자동차신품           1455      1330
# 대구_기타운송수단           74114     91660
# 대구_자동차부품및정비        340028    363007
# 대구_여행/교통           132271    148059
# 대구_여행사/자동차임대         5297      4817
# 대구_항공사                 41         0
# 대구_대중교통            126929    143241
# 대구_오락/문화           384951    425473
# 대구_스포츠/오락/여가       311526    348555
# 대구_서적/문구            73426     76916
# 대구_교육              423098    507424
# 대구_숙박/음식          1926290   1934406
# 대구_숙박               49109     57589
# 대구_음식점            1877180   1876813
# 대구_공과금/개인및전문서비스    435530    474500
# 대구_금융/보험            15553     11054
# 대구_기타              883274    921193

# %%
compare_df1['증감율'] = ((compare_df1['2021'] - compare_df1['2020'])/compare_df1['2020'] * 100)
compare_df1
# Out:
#                      2020      2021         증감율
# 대구_합계            12722569  13698697    7.672413
# 대구_종합소매           3311379   3631539    9.668480
# 대구_백화점            1038067   1337098   28.806522
# 대구_대형마트/유통전문점     1064951   1044531   -1.917459
# 대구_슈퍼마켓            902659    897714   -0.547826
# 대구_편의점             304334    352083   15.689670
# 대구_면세점               1367       114  -91.660571
# 대구_전자상거래/통신판매      125982     84050  -33.284120
# 대구_식료품             459621    507926   10.509746
# 대구_일반식료품           433357    483032   11.462835
# 대구_건강보조식품           26264     24893   -5.220073
# 대구_의류/잡화           505470    528994    4.653886
# 대구_의복/직물           258954    272334    5.166941
# 대구_복식잡화             37506     41103    9.590466
# 대구_시계/귀금속/안경       118672    129854    9.422610
# 대구_화장품              90339     85707   -5.127354
# 대구_연료             1133595   1321584   16.583436
# 대구_가구/가전           467335    422270   -9.642976
# 대구_가구               81432     64782  -20.446508
# 대구_가전제품/정보통신기기     385903    357488   -7.363249
# 대구_의료/보건          2102621   2324223   10.539322
# 대구_종합병원            354248    405855   14.568043
# 대구_일반병의원/기타의료기관   1748374   1918367    9.722920
# 대구_자동차             415598    455998    9.720932
# 대구_국산자동차신품           1455      1330   -8.591065
# 대구_기타운송수단           74114     91660   23.674340
# 대구_자동차부품및정비        340028    363007    6.757973
# 대구_여행/교통           132271    148059   11.936101
# 대구_여행사/자동차임대         5297      4817   -9.061733
# 대구_항공사                 41         0 -100.000000
# 대구_대중교통            126929    143241   12.851279
# 대구_오락/문화           384951    425473   10.526535
# 대구_스포츠/오락/여가       311526    348555   11.886327
# 대구_서적/문구            73426     76916    4.753085
# 대구_교육              423098    507424   19.930607
# 대구_숙박/음식          1926290   1934406    0.421328
# 대구_숙박               49109     57589   17.267711
# 대구_음식점            1877180   1876813   -0.019551
# 대구_공과금/개인및전문서비스    435530    474500    8.947719
# 대구_금융/보험            15553     11054  -28.926895
# 대구_기타              883274    921193    4.293005

# %%
compare_df1['증감율'] = ((compare_df1['2021'] - compare_df1['2020'])/compare_df1['2020'] * 100) > 10
compare_df1
# Out:
#                      2020      2021    증감율
# 대구_합계            12722569  13698697  False
# 대구_종합소매           3311379   3631539  False
# 대구_백화점            1038067   1337098   True
# 대구_대형마트/유통전문점     1064951   1044531  False
# 대구_슈퍼마켓            902659    897714  False
# 대구_편의점             304334    352083   True
# 대구_면세점               1367       114  False
# 대구_전자상거래/통신판매      125982     84050  False
# 대구_식료품             459621    507926   True
# 대구_일반식료품           433357    483032   True
# 대구_건강보조식품           26264     24893  False
# 대구_의류/잡화           505470    528994  False
# 대구_의복/직물           258954    272334  False
# 대구_복식잡화             37506     41103  False
# 대구_시계/귀금속/안경       118672    129854  False
# 대구_화장품              90339     85707  False
# 대구_연료             1133595   1321584   True
# 대구_가구/가전           467335    422270  False
# 대구_가구               81432     64782  False
# 대구_가전제품/정보통신기기     385903    357488  False
# 대구_의료/보건          2102621   2324223   True
# 대구_종합병원            354248    405855   True
# 대구_일반병의원/기타의료기관   1748374   1918367  False
# 대구_자동차             415598    455998  False
# 대구_국산자동차신품           1455      1330  False
# 대구_기타운송수단           74114     91660   True
# 대구_자동차부품및정비        340028    363007  False
# 대구_여행/교통           132271    148059   True
# 대구_여행사/자동차임대         5297      4817  False
# 대구_항공사                 41         0  False
# 대구_대중교통            126929    143241   True
# 대구_오락/문화           384951    425473   True
# 대구_스포츠/오락/여가       311526    348555   True
# 대구_서적/문구            73426     76916  False
# 대구_교육              423098    507424   True
# 대구_숙박/음식          1926290   1934406  False
# 대구_숙박               49109     57589   True
# 대구_음식점            1877180   1876813  False
# 대구_공과금/개인및전문서비스    435530    474500  False
# 대구_금융/보험            15553     11054  False
# 대구_기타              883274    921193  False

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['대구_백화점'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['대구_백화점'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['부산_전자상거래/통신판매'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['부산_전자상거래/통신판매'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['부산_일반식료품'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['부산_일반식료품'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['부산_여행/교통'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['부산_여행/교통'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['부산_여행사/자동차임대'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['부산_여행사/자동차임대'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['부산_항공사'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['부산_항공사'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(8,8)) ## Figure 생성 
fig.set_facecolor('white') ## Figure 배경색 지정
 
plt.bar(sum_df.index, sum_df['부산_금융/보험'], color='blue') ## 바차트 출력
plt.plot(sum_df.index, sum_df['부산_금융/보험'], color='red',
         linestyle='--', marker='o') ## 선 그래프 출력
plt.title('All region Total Summation ', fontsize=20)
plt.show()
